# %% [markdown]
# # Exercise1

# %%
library(readr)
iris2_1_ <- read_csv("F:/R/Lab1/iris2(1).csv")
mode(iris2_1_)
# Out:
# Parsed with column specification:
# cols(
#   Sepal.Length = col_double(),
#   Sepal.Width = col_double(),
#   Petal.Length = col_double(),
#   Petal.Width = col_double(),
#   Species = col_character()
# )
# [1] "list"

# %%
#convert the list data to data frame
iris2_1_ <- as.data.frame(iris2_1_)
iris2_1_
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.5         1.4          0.2         setosa
# 2   4.9          3.0         1.4          0.2         setosa
# 3   4.7          3.2         1.3          0.2         setosa
# 4   4.6          3.1         1.5          0.2         setosa
# 5   5.0          3.6         1.4          0.2         setosa
# 6   5.4          3.9         1.7          0.4         setosa
# 7   4.6          3.4         1.4          0.3         setosa
# 8   5.0          3.4         1.5          0.2         setosa
# 9   4.4          2.9         1.4           NA         setosa
# 10  4.9          3.1         1.5          0.1         setosa
# 11  5.4          3.7         1.5          0.2         setosa
# 12  4.8          3.4         1.6          0.2         setosa
# 13  4.8          3.0         1.4          0.1         setosa
# 14  4.3          3.0         1.1          0.1         setosa
# ...

# %% [markdown]
# We can see that there are NA values in the data frame. Thus, we have to replace those NA value by the mean value of the column

# %%
for(i in 1:ncol(iris2_1_)){
    iris2_1_[is.na(iris2_1_[,i]), i] <- mean(iris2_1_[,i], na.rm = TRUE)
}
iris2_1_
# Out:
# Warning message in mean.default(iris2_1_[, i], na.rm = TRUE):
# "argument is not numeric or logical: returning NA"
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.500000    1.4          0.200000    setosa
# 2   4.9          3.000000    1.4          0.200000    setosa
# 3   4.7          3.200000    1.3          0.200000    setosa
# 4   4.6          3.100000    1.5          0.200000    setosa
# 5   5.0          3.600000    1.4          0.200000    setosa
# 6   5.4          3.900000    1.7          0.400000    setosa
# 7   4.6          3.400000    1.4          0.300000    setosa
# 8   5.0          3.400000    1.5          0.200000    setosa
# 9   4.4          2.900000    1.4          1.198667    setosa
# 10  4.9          3.100000    1.5          0.100000    setosa
# 11  5.4          3.700000    1.5          0.200000    setosa
# 12  4.8          3.400000    1.6          0.200000    setosa
# 13  4.8          3.000000    1.4          0.100000    setosa
# ...

# %%
x <- iris[,4]
hist(x, breaks=20, main="Data")
# Out:
# Plot with title "Data"

# %%
### convert continuous variables into categories (there are 3 types of flowers) 
### default is equal interval width 
table(discretize(x, categories=3))
hist(x, breaks=20, main="Equal Interval length")
abline(v=discretize(x, categories=3, onlycuts=TRUE), col="red")

### equal frequency
table(discretize(x, "frequency", categories=3))
hist(x, breaks=20, main="Equal Frequency")
abline(v=discretize(x, method="frequency", categories=3, onlycuts=TRUE), col="red")

# %% [markdown]
# ![plot](Lab1/Rplot.png)

# %%
#install and use the plot package ggplot2
install.packages("ggplot2")
library(ggplot2)
species <- iris2_1_["Species"]
groups = table(species)
groups = as.data.frame(groups)
bp<- ggplot(groups, aes(x="", y=Freq, fill=species))+geom_bar(width = 1, stat = "identity")

# %% [markdown]
# Plot the bar chart:

# %% [markdown]
# ![bar](Lab1/Rplot_bar.png)

# %%
pie <- bp + coord_polar("y", start=0)
pie

# %% [markdown]
# Plot the pie chart:

# %% [markdown]
# ![pie plot](Lab1/Rplot_pie.png)

# %%
library(reshape2)
library(ggplot2)
gg1 <- melt(iris2_1_, id = 5)
gg1
# Out:
#     Species   variable     value
# 1   setosa    Sepal.Length 5.1
# 2   setosa    Sepal.Length 4.9
# 3   setosa    Sepal.Length 4.7
# 4   setosa    Sepal.Length 4.6
# 5   setosa    Sepal.Length 5.0
# 6   setosa    Sepal.Length 5.4
# 7   setosa    Sepal.Length 4.6
# 8   setosa    Sepal.Length 5.0
# 9   setosa    Sepal.Length 4.4
# 10  setosa    Sepal.Length 4.9
# 11  setosa    Sepal.Length 5.4
# 12  setosa    Sepal.Length 4.8
# 13  setosa    Sepal.Length 4.8
# 14  setosa    Sepal.Length 4.3
# 15  setosa    Sepal.Length 5.8
# 16  setosa    Sepal.Length 5.7
# 17  setosa    Sepal.Length 5.4
# 18  setosa    Sepal.Length 5.1
# 19  setosa    Sepal.Length 5.7
# 20  setosa    Sepal.Length 5.1
# 21  setosa    Sepal.Length 5.4
# 22  setosa    Sepal.Length 5.1
# 23  setosa    Sepal.Length 4.6
# 24  setosa    Sepal.Length 5.1
# 25  setosa    Sepal.Length 4.8
# 26  setosa    Sepal.Length 5.0
# 27  setosa    Sepal.Length 5.0
# 28  setosa    Sepal.Length 5.2
# 29  setosa    Sepal.Length 5.2
# ...

# %%
ggplot(gg1) +
     geom_bar(aes(x=Species, y=value, fill=variable), stat="identity",
              position="dodge")+facet_wrap(~variable)
# Out:
# plot without title
